# %%
import numpy as np

data = np.load(
    "./checkpoints_recurrent_ppo_risk/temp/run_Ratio_alpha_0.1_eps_0.233572_horizon_256_20260410_143901/"
    "inference_fullroute_best_test/routes/routes_0006_result_inference.npz",
    allow_pickle=True,
)

print(data.files)
# Out:
# ['frame_idx', 'action_idx', 'chosen_rate', 'global_best_rate', 'hit_global_best', 'reward', 'z_before', 'z_after', 'restricted_before_action', 'subset', 'serving_channel', 'global_best_channel']

# %%
data["subset"]
# Out:
# array([list([0, 1]), list([0, 1]), list([0, 1]), ..., list([0, 1]),
#        list([1]), list([1])], dtype=object)
