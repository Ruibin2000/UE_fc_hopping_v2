# %%
import numpy as np

CQI_array = np.load("../dataset/CQI_Mobility_medium_R_2_region_2/routes_0001_result.npz", allow_pickle=True)

# %%
print(CQI_array.files)
for k in CQI_array.files:
    arr = CQI_array[k]
    print(k, type(arr), arr.dtype, getattr(arr, "shape", None))
# Out:
# ['hp', 'sinr_db', 'sinr_lin', 'capacity', 'route_file']
# hp <class 'numpy.ndarray'> object (1200, 1, 4, 1, 2, 1, 1)
# sinr_db <class 'numpy.ndarray'> object (1200, 1, 4, 1, 2, 1, 1)
# sinr_lin <class 'numpy.ndarray'> object (1200, 1, 4, 1, 2, 1, 1)
# capacity <class 'numpy.ndarray'> object (1200, 1, 4, 1, 2, 1, 1)
# route_file <class 'numpy.ndarray'> <U15 ()
