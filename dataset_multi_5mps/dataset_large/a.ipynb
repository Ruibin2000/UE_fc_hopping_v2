# %%
import os
import glob

# 找到当前目录下所有 json 文件
for file in glob.glob("*.json"):
    if "R1" in file:  # 只改含有R1的
        new_name = file.replace("R1", "R2", 1)  # 只替换第一个出现的R1
        os.rename(file, new_name)
        print(f"{file} -> {new_name}")
# Out:
# 51_region_1_57_31_60s_R1_rate.json -> 51_region_1_57_31_60s_R2_rate.json
# 51_region_1_54_45_60s_R1_snr.json -> 51_region_1_54_45_60s_R2_snr.json
# 51_region_1_55_24_60s_R1_hp.json -> 51_region_1_55_24_60s_R2_hp.json
# 51_region_1_51_21_60s_R1_hp.json -> 51_region_1_51_21_60s_R2_hp.json
# 51_region_1_53_0_60s_R1_hp.json -> 51_region_1_53_0_60s_R2_hp.json
# 51_region_1_60_26_60s_R1_snr.json -> 51_region_1_60_26_60s_R2_snr.json
# 51_region_1_56_6_60s_R1_snr.json -> 51_region_1_56_6_60s_R2_snr.json
# 51_region_1_59_44_60s_R1_snr.json -> 51_region_1_59_44_60s_R2_snr.json
# 51_region_1_53_23_60s_R1_rate.json -> 51_region_1_53_23_60s_R2_rate.json
# 51_region_1_55_22_60s_R1_hp.json -> 51_region_1_55_22_60s_R2_hp.json
# 51_region_1_58_22_60s_R1_rate.json -> 51_region_1_58_22_60s_R2_rate.json
# 51_region_1_60_8_60s_R1_hp.json -> 51_region_1_60_8_60s_R2_hp.json
# 51_region_1_50_48_60s_R1_rate.json -> 51_region_1_50_48_60s_R2_rate.json
# ...
