# %%
# =====================
# TensorFlow / GPU
# =====================
import os
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    print("GPU available:", gpus)
else:
    print("No GPU, using CPU")

if os.getenv("CUDA_VISIBLE_DEVICES") is None:
    gpu_num = 0  # 使用 CPU 可设为 ""
    os.environ["CUDA_VISIBLE_DEVICES"] = f"{gpu_num}"

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"


# =====================
# Scientific stack
# =====================
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation as R

# %matplotlib inline


# =====================
# Mitsuba / DrJit
# =====================
import mitsuba as mi
import drjit as dr


# =====================
# Sionna RT
# =====================
from sionna.rt import (
    load_scene,
    PlanarArray,
    Transmitter,
    Receiver,
    Camera,
    PathSolver,
    ITURadioMaterial,
    SceneObject,
    AntennaPattern,
    register_antenna_pattern,
)


# =====================
# Custom utils / scenes
# =====================
import sionnautils
from sionnautils.custom_scene import list_scenes, get_scene


# =====================
# Project-specific
# =====================
from Engine_V3 import Engine


# =====================
# Misc
# =====================
import json
from pathlib import Path
import yaml
# Out:
# 2026-02-16 00:03:20.298066: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
import yaml
import numpy as np

def normalize_config(obj):
    """Recursively normalize:
    - numeric strings (incl. scientific notation) -> float
    - 'np.pi', 'np.e', 'np.inf' -> numpy constants
    """
    if isinstance(obj, dict):
        return {k: normalize_config(v) for k, v in obj.items()}

    if isinstance(obj, list):
        return [normalize_config(v) for v in obj]

    if isinstance(obj, str):
        s = obj.strip()

        # numpy constants
        if s == "np.pi":
            return np.pi
        if s == "np.e":
            return np.e
        if s in ("np.inf", "inf"):
            return np.inf
        if s in ("-np.inf", "-inf"):
            return -np.inf

        # numeric strings (supports "15.0e9", "200.0e6", "3.5E9", etc.)
        try:
            return float(s)
        except ValueError:
            return obj  # keep as string if not numeric

    return obj  # int/float/bool/None stay as-is


with open("config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

cfg = normalize_config(cfg)

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

result_dir = Path(cfg["experiment"]["CQI_dir"])   # 你存 result.npz 的目录
npz_files = sorted(result_dir.glob("*_result.npz"))

print(f"Found {len(npz_files)} result files")
# Out:
# Found 136 result files

# %%
def load_sinr_db(npz_path):
    data = np.load(npz_path, allow_pickle=True)
    sinr_db = data["sinr_db"]

    # 如果是 object array（很常见）
    if sinr_db.dtype == object:
        sinr_db = np.stack(sinr_db, axis=0)
    sinr_db = np.squeeze(sinr_db, axis=(3,5,6))  # -> (N, U, R, T)

    
    return sinr_db


def load_capacity(npz_path):
    data = np.load(npz_path, allow_pickle=True)
    cap = data["capacity"]

    # object array -> stack
    if cap.dtype == object:
        cap = np.stack(cap, axis=0)
    cap = np.squeeze(cap, axis=(3,5,6))
    return cap

# %%
dt = cfg["channel"]["measure_time"]
rx_fc = cfg["ue"]["rx_fc"]


for npz_path in npz_files:
    print(f"Plotting {npz_path.name}")

    sinr_db = load_sinr_db(npz_path)
    capacity = load_capacity(npz_path)

    out_dir = Path(cfg["experiment"]["CQI_dir"]) / "pdf"/ npz_path.stem
    out_dir.mkdir(parents=True, exist_ok=True)


    # print("sinr_db.shape =", sinr_db.shape)
    # print("sinr_db.ndim  =", sinr_db.ndim)
    # print("example slice shapes:")
    # print("sinr_db[0].shape =", sinr_db[0].shape)

    t_axis = np.arange(sinr_db.shape[0]) * dt


    U = sinr_db.shape[1]
    R = sinr_db.shape[2]

    # plt.figure(figsize=(15, 2.6))

    for tx_id in range(cfg["tx"]["n_tx"]):
        

        for u in range(U):
            ############################################################################################################################
            plt.figure(figsize=(10, 2.6))
            for r in range(R):
                y = sinr_db[:, u, r, tx_id]
                y = np.where(y <= -1000, np.nan, y)  # 把 -3000 这种无效值隐藏掉
                plt.plot(t_axis, y, label=f"UE {u}, RX{r}, fc = {rx_fc[r]/1e9} GHz,  BW = {cfg['ue']['rx_bw'][r]/1e6} MHz")
            plt.ylim(-70, 70)
            plt.xlabel("Time (s)")
            plt.ylabel(f"SINR (dB), serving TX={tx_id}")
            plt.title(f"UE {u}: SINR vs Time")
            # plt.legend(loc="upper left", ncol=2)
            plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
            
            out_pdf = out_dir / f"SINR_{npz_path.stem}_tx{tx_id}_ue{u}.pdf"
            plt.savefig(out_pdf, format="pdf", bbox_inches="tight")
            plt.close()

            ############################################################################################################################
            plt.figure(figsize=(15, 2.6))
            for r in range(R):
                y = capacity[:, u, r, tx_id]
                y = np.where(y <= -1000, np.nan, y)  # 把 -3000 这种无效值隐藏掉
                plt.plot(t_axis, y, label=f"UE {u}, RX{r}, fc = {rx_fc[r]/1e9} GHz, BW = {cfg['ue']['rx_bw'][r]/1e6} MHz")
            plt.ylim(0, 1000)
            plt.xlabel("Time (s)")
            plt.ylabel(f"Capacity (bps), serving TX={tx_id}")
            plt.title(f"UE {u}: Capacity vs Time, serving TX={tx_id}")
            plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
            plt.grid(True)

            out_pdf = out_dir/ f"Capacity_{npz_path.stem}_tx{tx_id}_ue{u}.pdf"
            plt.savefig(out_pdf, format="pdf", bbox_inches="tight")
            plt.close()
# Out:
# Plotting routes_0000_result.npz
# Plotting routes_0001_result.npz
# Plotting routes_0002_result.npz
# Plotting routes_0003_result.npz
# Plotting routes_0004_result.npz
# Plotting routes_0005_result.npz
# Plotting routes_0006_result.npz
# Plotting routes_0007_result.npz
# Plotting routes_0008_result.npz
# Plotting routes_0009_result.npz
# Plotting routes_0010_result.npz
# Plotting routes_0011_result.npz
# Plotting routes_0012_result.npz
# Plotting routes_0013_result.npz
# Plotting routes_0014_result.npz
# Plotting routes_0015_result.npz
# Plotting routes_0016_result.npz
# Plotting routes_0017_result.npz
# Plotting routes_0018_result.npz
# Plotting routes_0019_result.npz
# Plotting routes_0020_result.npz
# Plotting routes_0021_result.npz
# Plotting routes_0022_result.npz
# Plotting routes_0023_result.npz
# Plotting routes_0024_result.npz
# Plotting routes_0025_result.npz
# Plotting routes_0026_result.npz
# Plotting routes_0027_result.npz
# Plotting routes_0028_result.npz
# Plotting routes_0029_result.npz
# Plotting routes_0030_result.npz
# Plotting routes_0031_result.npz
# Plotting routes_0032_result.npz
# Plotting routes_0033_result.npz
# Plotting routes_0034_result.npz
# Plotting routes_0035_result.npz
# Plotting routes_0036_result.npz
# Plotting routes_0037_result.npz
# Plotting routes_0038_result.npz
# Plotting routes_0039_result.npz
# Plotting routes_0040_result.npz
# Plotting routes_0041_result.npz
# Plotting routes_0042_result.npz
# Plotting routes_0043_result.npz
# Plotting routes_0044_result.npz
# Plotting routes_0045_result.npz
# Plotting routes_0046_result.npz
# Plotting routes_0047_result.npz
# Plotting routes_0048_result.npz
# Plotting routes_0049_result.npz
# Plotting routes_0050_result.npz
# Plotting routes_0051_result.npz
# Plotting routes_0052_result.npz
# Plotting routes_0053_result.npz
# Plotting routes_0054_result.npz
# Plotting routes_0055_result.npz
# Plotting routes_0056_result.npz
# Plotting routes_0057_result.npz
# Plotting routes_0058_result.npz
# Plotting routes_0059_result.npz
# Plotting routes_0060_result.npz
# Plotting routes_0061_result.npz
# Plotting routes_0062_result.npz
# Plotting routes_0063_result.npz
# Plotting routes_0064_result.npz
# Plotting routes_0065_result.npz
# Plotting routes_0066_result.npz
# Plotting routes_0067_result.npz
# Plotting routes_0068_result.npz
# Plotting routes_0069_result.npz
# Plotting routes_0070_result.npz
# Plotting routes_0071_result.npz
# Plotting routes_0072_result.npz
# Plotting routes_0073_result.npz
# Plotting routes_0074_result.npz
# Plotting routes_0075_result.npz
# Plotting routes_0076_result.npz
# Plotting routes_0077_result.npz
# Plotting routes_0078_result.npz
# Plotting routes_0079_result.npz
# Plotting routes_0080_result.npz
# Plotting routes_0081_result.npz
# Plotting routes_0082_result.npz
# Plotting routes_0083_result.npz
# Plotting routes_0084_result.npz
# Plotting routes_0085_result.npz
# Plotting routes_0086_result.npz
# Plotting routes_0087_result.npz
# Plotting routes_0088_result.npz
# Plotting routes_0089_result.npz
# Plotting routes_0090_result.npz
# Plotting routes_0091_result.npz
# Plotting routes_0092_result.npz
# Plotting routes_0093_result.npz
# Plotting routes_0094_result.npz
# Plotting routes_0095_result.npz
# Plotting routes_0096_result.npz
# Plotting routes_0097_result.npz
# Plotting routes_0098_result.npz
# Plotting routes_0099_result.npz
# Plotting routes_0100_result.npz
# Plotting routes_0101_result.npz
# Plotting routes_0102_result.npz
# Plotting routes_0103_result.npz
# Plotting routes_0104_result.npz
# Plotting routes_0105_result.npz
# Plotting routes_0106_result.npz
# Plotting routes_0107_result.npz
# Plotting routes_0108_result.npz
# Plotting routes_0109_result.npz
# Plotting routes_0110_result.npz
# Plotting routes_0111_result.npz
# Plotting routes_0112_result.npz
# Plotting routes_0113_result.npz
# Plotting routes_0114_result.npz
# Plotting routes_0115_result.npz
# Plotting routes_0116_result.npz
# Plotting routes_0117_result.npz
# Plotting routes_0118_result.npz
# Plotting routes_0119_result.npz
# Plotting routes_0120_result.npz
# Plotting routes_0121_result.npz
# Plotting routes_0122_result.npz
# Plotting routes_0123_result.npz
# Plotting routes_0124_result.npz
# Plotting routes_0125_result.npz
# Plotting routes_0126_result.npz
# Plotting routes_0127_result.npz
# Plotting routes_0128_result.npz
# Plotting routes_0129_result.npz
# Plotting routes_0130_result.npz
# Plotting routes_0131_result.npz
# Plotting routes_0132_result.npz
# Plotting routes_0133_result.npz
# Plotting routes_0134_result.npz
# Plotting routes_0135_result.npz
